# %%
# install.packages("remotes")

# if (!requireNamespace("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")
# BiocManager::install("git.bioconductor.org:packages/maftools")
# library(maftools)
BiocManager::install(version='devel')

# BiocManager::install("maftools")
# Out:
# Error: Bioconductor version '3.13' requires R version '4.1'; see
#   https://bioconductor.org/install
# Traceback:
#
# 1. BiocManager::install(version = "devel")
# 2. .version_validate(version)
# 3. ifelse(.is_CRAN_check(), .message(txt), .stop(txt))
# 4. .stop(txt)
# 5. stop(.msg(...), call. = call.)

# %%
install.packages("installr")

library(installr)

updateR()
# if (!requireNamespace("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")

# # The following initializes usage of Bioc devel
# BiocManager::install(version='devel')

# BiocManager::install("maftools")
# Out:
# Warning message:
# “package ‘installr’ is not available (for R version 4.0.0)”
# Error in library(installr): there is no package called ‘installr’
# Traceback:
#
# 1. library(installr)

# %%
library(maftools)

# %%
maf = "/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/patients/final.maf"
maf="/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/sample_mafs_merged"
cn = "/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/cna_annotation/patients/annos_final_filt2.tsv"
cn="/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/cna_annotation/annos_filt_sample_merged.tsv"
# maf = "/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/SA906b_SA906_A96220B/museq.maf"
# maf = "/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/t"
# maf="/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/patients/SA1101b/patient_maf.maf"

genes=c("TP53",  "BRCA1", "BRCA2", "MECOM", "RB1", "PTEN", "PALB2","ERBB2", "CDK12", "PIK3CA", "KRAS", "CCNE1", "MYC")

laml.plus.cn = read.maf(maf = maf,
                        cnTable = cn,
                        verbose = FALSE)

oncoplot(maf = laml.plus.cn, genes=genes)
# Out:
# Plot with title “Altered in 126 (90.65%) of 139 samples.”

# %%
?oncoplot

# %%
maf = "/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/patients/final.maf"
maf="/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/sample_mafs_merged"
cn = "/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/cna_annotation/patients/annos_final_filt2.tsv"
cn="/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/cna_annotation/annos_filt_sample_merged_no_deep.tsv"
# maf = "/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/SA906b_SA906_A96220B/museq.maf"
# maf = "/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/t"
# maf="/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/patients/SA1101b/patient_maf.maf"

genes=c("TP53",  "BRCA1", "BRCA2", "MECOM", "RB1", "PTEN", "PALB2","ERBB2", "CDK12", "PIK3CA", "KRAS", "CCNE1", "MYC")

laml.plus.cn = read.maf(maf = maf,
                        cnTable = cn,
                        verbose = FALSE)

oncoplot(maf = laml.plus.cn, genes=genes)

# %%
maf = "/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/patients/final.maf"
maf="/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/sample_mafs_merged"
cn = "/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/cna_annotation/patients/annos_final_filt2.tsv"
cn="/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/cna_annotation/annos_filt_sample_merged.tsv"
cn="/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/cna_annotation/annos_filt_sample_merged_deep_only.tsv"
# maf = "/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/SA906b_SA906_A96220B/museq.maf"
# maf = "/juno/work/shah/abramsd/RESULTS/dlp_cohort_oncoplot/t"
# maf="/juno/work/shah/abramsd/CODE/wgs_cohort_qc_TESTRUNS/MAFS_COMPLETE/patients/SA1101b/patient_maf.maf"

genes=c("TP53",  "BRCA1", "BRCA2", "MECOM", "RB1", "PTEN", "PALB2","ERBB2", "CDK12", "PIK3CA", "KRAS", "CCNE1", "MYC")

laml.plus.cn = read.maf(maf = maf,
                        cnTable = cn,
                        verbose = FALSE)

oncoplot(maf = laml.plus.cn, genes=genes)
# Out:
# Plot with title “Altered in 120 (86.33%) of 139 samples.”

# %%
?oncoplot

# %%
#path to TCGA LAML MAF file
laml.maf = system.file('extdata', 'tcga_laml.maf.gz', package = 'maftools')
#clinical information containing survival information and histology. This is optional
laml.clin = system.file('extdata', 'tcga_laml_annot.tsv', package = 'maftools')

laml = read.maf(maf = laml.maf,
                clinicalData = laml.clin,
                verbose = FALSE)
set.seed(seed = 1024)
barcodes = as.character(getSampleSummary(x = laml)[,Tumor_Sample_Barcode])
#Random 20 samples
dummy.samples = sample(x = barcodes,
                       size = 20,
                       replace = FALSE)

#Genarate random CN status for above samples
cn.status = sample(
  x = c('ShallowAmp', 'DeepDel', 'Del', 'Amp'),
  size = length(dummy.samples),
  replace = TRUE
)

custom.cn.data = data.frame(
  Gene = "DNMT3A",
  Sample_name = dummy.samples,
  CN = cn.status,
  stringsAsFactors = FALSE
)

head(custom.cn.data)
#>     Gene  Sample_name         CN
#> 1 DNMT3A TCGA-AB-2898 ShallowAmp
#> 2 DNMT3A TCGA-AB-2879        Del
#> 3 DNMT3A TCGA-AB-2920        Amp
#> 4 DNMT3A TCGA-AB-2866        Del
#> 5 DNMT3A TCGA-AB-2892        Del
#> 6 DNMT3A TCGA-AB-2863 ShallowAmp

laml.plus.cn = read.maf(maf = laml.maf,
                        cnTable = custom.cn.data,
                        verbose = FALSE)

oncoplot(maf = laml.plus.cn, top = 5)
# Out:
#   Gene   Sample_name  CN
# 1 DNMT3A TCGA-AB-2898 ShallowAmp
# 2 DNMT3A TCGA-AB-2879 Del
# 3 DNMT3A TCGA-AB-2920 Amp
# 4 DNMT3A TCGA-AB-2866 Del
# 5 DNMT3A TCGA-AB-2892 Del
# 6 DNMT3A TCGA-AB-2863 ShallowAmp
# Plot with title “Altered in 115 (59.59%) of 193 samples.”

# %%
sessionInfo()
# Out:
# R version 4.0.0 (2020-04-24)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS/LAPACK: /home/abramsd/miniconda3/envs/r-environment/lib/libopenblasp-r0.3.9.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] maftools_2.6.05
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.4.6        pillar_1.4.4        compiler_4.0.0
#  [4] RColorBrewer_1.1-2  BiocManager_1.30.10 prettyunits_1.1.1
#  [7] R.methodsS3_1.8.0   R.utils_2.9.2       base64enc_0.1-3
# ...

# %%
#path to TCGA LAML MAF file
laml.maf = system.file('extdata', 'tcga_laml.maf.gz', package = 'maftools')

#Random 20 samples
dummy.samples = c("TCGA-AB-2898", "TCGA-AB-2879", "TCGA-AB-2920", "TCGA-AB-2866", 
                  "TCGA-AB-2892", "TCGA-AB-2863", "TCGA-AB-2994", "TCGA-AB-3007", 
                  "TCGA-AB-2992", "TCGA-AB-2860", "TCGA-AB-2917", "TCGA-AB-2859", 
                  "TCGA-AB-2822", "TCGA-AB-2936", "TCGA-AB-2897", "TCGA-AB-3008", 
                  "TCGA-AB-2883", "TCGA-AB-2957", "TCGA-AB-2946", "TCGA-AB-2943"
)

#Genarate random germline status for above samples
gl.status = sample(
  x = c('Germline', 'idk,maybe..'),
  size = length(dummy.samples),
  replace = TRUE
)

gl.data = data.frame(
  Gene = "NPM1",
  Sample_name = dummy.samples,
  is_germline = gl.status,
  stringsAsFactors = FALSE
)

head(gl.data)

laml.plus.cn = read.maf(maf = laml.maf, cnTable = gl.data)

#maftools default colors for known variant classifications
vc_cols = maftools:::get_vcColors()
#colors for your additional values
my_cols = c("#f3a683", "#f7d794")
#Set alpha if you would like
#my_cols = grDevices::adjustcolor(col = my_cols, alpha.f = 0.9)
names(my_cols) = c('Germline', 'idk,maybe..')

vc_cols = c(vc_cols, my_cols)

oncoplot(
  maf = laml.plus.cn,
  genes = c("DNMT3A", "NPM1"),
  drawRowBar = FALSE,
  drawColBar = FALSE,
  showTitle = FALSE, colors = vc_cols
)

# oncoplot(
#   maf = laml.plus.cn,
#   genes = c("DNMT3A", "NPM1"),
#   drawRowBar = FALSE,
#   drawColBar = FALSE,
#   showTitle = FALSE
# )
# Out:
#   Gene Sample_name  is_germline
# 1 NPM1 TCGA-AB-2898 idk,maybe..
# 2 NPM1 TCGA-AB-2879 idk,maybe..
# 3 NPM1 TCGA-AB-2920 idk,maybe..
# 4 NPM1 TCGA-AB-2866 idk,maybe..
# 5 NPM1 TCGA-AB-2892 Germline
# 6 NPM1 TCGA-AB-2863 idk,maybe..
# -Reading
# -Validating
# -Silent variants: 475
# -Processing copy number data
# -Summarizing
# -Processing clinical data
# --Missing clinical data
# -Finished in 0.405s elapsed (8.603s cpu)
# plot without title

# %%
laml.maf = system.file('extdata', 'tcga_laml.maf.gz', package = 'maftools')

# #Random 20 samples
dummy.samples = c("TCGA-AB-2898", "TCGA-AB-2879", "TCGA-AB-2920", "TCGA-AB-2866", 
                  "TCGA-AB-2892", "TCGA-AB-2863", "TCGA-AB-2994", "TCGA-AB-3007", 
                  "TCGA-AB-2992", "TCGA-AB-2860", "TCGA-AB-2917", "TCGA-AB-2859", 
                  "TCGA-AB-2822", "TCGA-AB-2936", "TCGA-AB-2897", "TCGA-AB-3008", 
                  "TCGA-AB-2883", "TCGA-AB-2957", "TCGA-AB-2946", "TCGA-AB-2943"
)



laml = read.maf(maf = laml.maf)
samples = getClinicalData(laml)$Tumor_Sample_Barcode

label = sample(
  x = c('ppppp', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8','p9', 'p10', 'p11',
        'p12','ppppp2', 'p14', 'p15', 'p16',
       'p17', 'p18', 'p19', 'p20', 'p21', 'ppppp2', 'p23', 'p24','p25', 'p26', 'p27',
        'p28','p29', 'p30', 'p31', 'p32'),
  size = length(samples),
  replace = TRUE
)

g1.annotation = data.frame(
    Tumor_Sample_Barcode=samples,
    Patient=label
)


# nrow(getClinicalData(laml))


# samps = laml.maf.
# #Genarate random germline status for above samples
gl.status = sample(
  x = c('DeepDel', 'idk,maybe..'),
  size = length(dummy.samples),
  replace = TRUE
)


gl.data = data.frame(
  Gene = "NPM1",
  Sample_name = dummy.samples,
  is_germline = gl.status,
  stringsAsFactors = FALSE
)


gl.data
lamlw = read.maf(maf = laml.maf, clinicalData=g1.annotation, cnTable=gl.data
)



# # # print(label)


laml=read.maf(maf=maf, clinicalData=patients, cnTable=cn)



# # laml.plus.cn = read.maf(maf = laml.maf, clinicalData=g1.annotation)
# # getClinicalData(laml.plus.cn)
genes=c("TP53",  "BRCA1", "BRCA2", "MECOM", "RB1", "PTEN", "PALB2","ERBB2", "CDK12", "PIK3CA", "KRAS", "CCNE1", "MYC")

oncoplot(
  maf = laml,
  genes = genes,
  drawRowBar = FALSE,
  drawColBar = FALSE,
  showTitle = FALSE,
  clinicalFeatures="Patient",
  sortByAnnotation=TRUE
)
# Out:
# -Reading
# -Validating
# -Silent variants: 475
# -Summarizing
# -Processing clinical data
# --Missing clinical data
# -Finished in 0.334s elapsed (7.617s cpu)
#    Gene Sample_name  is_germline
# 1  NPM1 TCGA-AB-2898 DeepDel
# 2  NPM1 TCGA-AB-2879 idk,maybe..
# 3  NPM1 TCGA-AB-2920 DeepDel
# 4  NPM1 TCGA-AB-2866 idk,maybe..
# 5  NPM1 TCGA-AB-2892 DeepDel
# 6  NPM1 TCGA-AB-2863 idk,maybe..
# 7  NPM1 TCGA-AB-2994 DeepDel
# 8  NPM1 TCGA-AB-3007 idk,maybe..
# 9  NPM1 TCGA-AB-2992 DeepDel
# 10 NPM1 TCGA-AB-2860 idk,maybe..
# 11 NPM1 TCGA-AB-2917 DeepDel
# 12 NPM1 TCGA-AB-2859 idk,maybe..
# 13 NPM1 TCGA-AB-2822 idk,maybe..
# 14 NPM1 TCGA-AB-2936 DeepDel
# 15 NPM1 TCGA-AB-2897 idk,maybe..
# 16 NPM1 TCGA-AB-3008 DeepDel
# 17 NPM1 TCGA-AB-2883 idk,maybe..
# 18 NPM1 TCGA-AB-2957 DeepDel
# 19 NPM1 TCGA-AB-2946 DeepDel
# 20 NPM1 TCGA-AB-2943 DeepDel
# -Reading
# -Validating
# -Silent variants: 475
# -Processing copy number data
# -Summarizing
# -Processing clinical data
# ...

# %%
sessionInfo()
# Out:
# R version 4.0.0 (2020-04-24)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS/LAPACK: /home/abramsd/miniconda3/envs/r-environment/lib/libopenblasp-r0.3.9.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] maftools_2.6.05
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.4.6       lattice_0.20-41    digest_0.6.25      crayon_1.3.4
#  [5] R.methodsS3_1.8.0  IRdisplay_0.7.0    grid_4.0.0         repr_1.1.0
#  [9] jsonlite_1.6.1     evaluate_0.14      pillar_1.4.4       rlang_0.4.6
# ...
